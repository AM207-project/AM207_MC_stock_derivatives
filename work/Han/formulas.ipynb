# %% [markdown]
# $$y_{t,j} = \sum_{r=1}^{R} b_{rj} y_{t-r,j} + \sum_{s=1}^{S} a_{sj} \epsilon_{t-s,j} + \epsilon_{t,j}$$
#
#
#
# $$ \sigma_{t,j}^2 = \delta_{0j} + \sum_{q=1}^{Q} \delta_{qj} \epsilon_{t-q,j}^2 + \sum_{p=1}^{P} \beta_{pj} \sigma_{t-p,j}^2 $$
#
#
# $$ y_t = \ln p_t - \ln p_{t-1}  $$
#
#
# $$p(y_t) = \sum_{j=1}^{K} \alpha_j G(y_t; \hat{y_{t,j}}, \sigma_{t,j}^2)  $$
#
#
# $$ p(\mathbf{y}) = \prod_{t=1}^{T} \sum_{j=1}^{K} \alpha_j G(y_t; \hat{y_{t,j}}, \sigma_{t,j}^2) $$
#
#
# $$ \hat{\Theta} = arg\max_\Theta \ln p(\mathbf{y}) $$
#
# $$ Q(\Theta, \Theta^*) = \sum_{t=1}^{T} \sum_{j=1}^{K} p(Z_t = j | y_t, \Theta^*) \ln \alpha_j G(y_t; \hat{y_{t,j}}, \sigma_{t,j}^2) $$
#
#
# $$ h_j(t) = p(Z_t = j | y_t, \Theta^*) $$
#
# $$= \frac{\alpha_j G(y_t; \hat{y_{t,j}}, \sigma_{t,j}^2)}{\sum_{i=1}^{K} \alpha_i G(y_t; \hat{y_{t,j}}, \sigma_{t,i}^2)}$$
#
#
# $$ \eta_j = e^{\psi_j} $$
#
#
# $$ \delta_{qj} = e^{\gamma_{qj}}, where q = 1, ..., Q $$
#
#
# $$ \beta_{pj} = e^{\rho_{pj}}, p = 1, ..., P $$
#
#
# $$ \frac{\partial Q(\Theta, \Theta^*)}{\partial m_j} = h_j(t) - \alpha_j $$
#
#
#
#
# $$ \frac{\partial Q(\Theta, \Theta^*)}{\partial \omega} = h_j(t) \big[ \frac{1}{2\sigma_{t,j}^2} (\frac{\epsilon_{t,j}^2}{\sigma_{t,j}^2} - 1) \frac{\partial \sigma_{t,j}^2}{\partial \omega} - \frac{\epsilon_{t,j}}{\sigma_{t,j}^2} \frac{\partial \epsilon_{t,j}}{\partial \omega} \big] $$
#
#
#
# $$ \frac{\partial \sigma_{t,j}^2}{\partial \alpha_{sj}}
# = 2 \sum_{c=1}^{Q} \epsilon_{t-c,j} e^{\gamma_{cj}} \frac{\partial \epsilon_{t-c,j}}{\partial \alpha_{sj}}
# + \sum_{d=1}^{P} e^{\rho_{dj}} \frac{\partial \sigma_{t-d,j}^2}{\partial \alpha_{sj}} $$
#
#
#
# $$ \frac{\partial \epsilon_{t,j}}{\partial \alpha_{sj}}
# = -\epsilon_{t-s, j} - \sum_{c=1}^{S} \alpha_{cj} \frac{\partial \epsilon_{t-c,j}}{\partial \alpha_{sj}} $$
#
#
#
# $$ \frac{\partial \sigma_{t,j}^2}{\partial b_{rj}}
# = 2 \sum_{c=1}^{Q} \epsilon_{t-c,j} e^{\gamma_{cj}} \frac{\partial \epsilon_{t-c,j}}{\partial b_{rj}}
# + \sum_{d=1}^{P} e^{\rho_{dj}} \frac{\partial \sigma_{t-d,j}^2}{\partial b_{rj}}$$
#
#
#
# $$ \frac{\partial \epsilon_{t,j}}{\partial b_{rj}}
# = -y_{t-r, j} - \sum_{c=1}^{S} \alpha_{cj} \frac{\partial \epsilon_{t-c,j}}{\partial b_{rj}} $$
#
#
#
# $$ \frac{\partial \sigma_{t,j}^2}{\partial \gamma_{0,j}}
# = e^{\gamma_{j0}} + \sum_{c=1}^{P} e^{\rho_{cj}} \frac{\partial \sigma_{t-c,j}^2}{\partial \gamma_{0j}} $$
#
#
#
# $$ \frac{\partial \sigma_{t,j}^2}{\partial \gamma_{q,j}}
# = \epsilon_{t-q,j}^2 e^{\gamma_{qj}} + \sum_{c=1}^{P} e^{\rho_{cj}} \frac{\partial \sigma_{t-c,j}^2}{\partial \gamma_{qj}} $$
#
#
#
# $$ \frac{\partial \sigma_{t,j}^2}{\partial \rho_{p,j}}
# = \sigma_{t-p,j}^2 e^{\rho_{pj}} + \sum_{c=1}^{P} e^{\rho_{cj}} \frac{\partial \sigma_{t-c,j}^2}{\partial \rho_{pj}} $$
#
#
#
# $$\frac{\partial \epsilon_{t,j}}{\partial \gamma_{0j}} = \frac{\partial \epsilon_{t,j}}{\partial \gamma_{qj}}
# = \frac{\partial \epsilon_{t,j}}{\partial \rho_{pj}} = 0$$
#
#
#
# $$ \theta^{(n+1)} = \theta^{(n)} + \lambda_n \frac{\partial E(l_t)}{\partial \theta}  $$
